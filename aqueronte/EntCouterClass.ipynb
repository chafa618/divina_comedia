# %%
import re 
import json
import argparse

class Counter_entities(object):
    """
    Count ent ocurrences for intent in file. The order of ents matters
    """
    
    def __init__(self, path):
        self.json_path = path
        
    
    def load_json(self):
        with open(self.json_path) as f:
            archivo = json.load(f)
        return archivo
        
    def get_keys(self):
        open_file = self.load_json()
        
        entidadRe = re.compile(r'\[.+?\]')
        entidades = []
        dic = {}

        for intent in open_file['intents'].keys():
            dic[intent] = []

            for utterance in open_file['intents'][intent]:
                ent = re.findall(entidadRe,utterance)

                if len(ent) >= 1:  
                    dic[intent].append(ent)
        return dic

    def count_ents_for_intent(self):
        claves = self.get_keys()

        output = {}
        for intent in claves:
            output[intent] = {}

            for utt in claves[intent]:
                #print(utt)
                key = ",".join(claves[intent][claves[intent].index(utt)])
                output[intent][key] = claves[intent].count(utt) 

        return output
    
    def save(self):
        with open('output.json', 'w') as file:
            json.dump(output, file, indent=4)

# %%
if __name__ == "__main__":
    parser = argparse.ArgumentParser()
    parser.add_argument('path')
    args = parser.parse_args()
    Counter_entities(args.path).count_ents_for_intent()
    Counter_entities.save()
# Out:
# usage: ipykernel_launcher.py [-h] path
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/fernando/.pyenv/versions/3.6.5/envs/charuto/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
conter = Counter_entities("/home/fernando/Escritorio/mios/divina_comedia/aqueronte/resources/luis_trainingset.tv.tef.json")

# %%
conter.count_ents_for_intent()
# Out:
# {'intent.tv.content_get_info': {'[ent.audiovisual_channel]': 23,
#   '[ent.audiovisual_channel],[ent.time_interval]': 13,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_channel],[ent.time_instant]': 3,
#   '[ent.time_interval],[ent.audiovisual_genre]': 6,
#   '[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.time_interval]': 1,
#   '[ent.audiovisual_genre],[ent.time_instant]': 6,
#   '[ent.audiovisual_genre],[ent.time_interval],[ent.device_tv]': 3,
#   '[ent.time_interval],[ent.audiovisual_channel]': 8,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.time_instant],[ent.audiovisual_channel]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_channel],[ent.time_interval]': 3,
#   '[ent.audiovisual_genre],[ent.device_tv]': 1,
#   '[ent.audiovisual_subgenre],[ent.device_tv]': 3,
#   '[ent.device_tv],[ent.time_interval]': 4,
#   '[ent.time_instant]': 8,
#   '[ent.time_interval],[ent.device_tv]': 3,
#   '[ent.time_instant],[ent.audiovisual_genre]': 5,
#   '[ent.audiovisual_channel],[ent.time_instant]': 4,
#   '[ent.audiovisual_genre],[ent.audiovisual_channel]': 10,
#   '[ent.device_tv],[ent.time_instant]': 4,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.time_instant]': 3,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.audiovisual_channel]': 3,
#   '[ent.audiovisual_genre],[ent.time_instant],[ent.device_tv]': 3,
#   '[ent.audiovisual_genre],[ent.time_interval]': 3,
#   '[ent.time_instant],[ent.time_interval],[ent.audiovisual_channel]': 1,
#   '[ent.time_instant],[ent.time_interval],[ent.audiovisual_genre]': 3,
#   '[ent.time_instant],[ent.device_tv]': 3,
#   '[ent.time_instant],[ent.audiovisual_channel]': 3,
#   '[ent.time_instant],[ent.audiovisual_sports_unit]': 1,
#   '[ent.time_interval],[ent.time_instant],[ent.audiovisual_sports_unit]': 1,
#   '[ent.time_interval],[ent.time_instant]': 2,
#   '[ent.time_interval],[ent.audiovisual_sports_unit]': 1,
#   '[ent.time_interval]': 6,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.audiovisual_channel],[ent.time_interval]': 2,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.time_instant],[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.time_interval],[ent.audiovisual_channel]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.audiovisual_channel],[ent.time_instant]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.device_tv],[ent.time_interval]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.device_tv],[ent.time_instant]': 2,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre],[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.device_tv],[ent.time_instant]': 1,
#   '[ent.audiovisual_genre],[ent.device_tv],[ent.time_interval]': 1,
#   '[ent.audiovisual_genre],[ent.time_interval],[ent.audiovisual_channel]': 1,
#   '[ent.audiovisual_subgenre],[ent.time_instant],[ent.audiovisual_channel]': 2,
#   '[ent.audiovisual_subgenre],[ent.time_instant]': 5,
#   '[ent.audiovisual_subgenre],[ent.time_instant],[ent.device_tv]': 2,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_channel]': 2,
#   '[ent.audiovisual_subgenre],[ent.time_interval],[ent.device_tv]': 1,
#   '[ent.audiovisual_subgenre],[ent.time_interval]': 1,
#   '[ent.time_instant],[ent.time_interval]': 1},
#  'intent.tv.display': {'[ent.audiovisual_sports_unit],[ent.audiovisual_sports],[ent.device_tv]': 6,
#   '[ent.audiovisual_tv_episode_number],[ent.audiovisual_tv_season_number],[ent.audiovisual_tvseries_title],[ent.device_tv]': 1,
#   '[ent.audiovisual_sports_season],[ent.device_tv]': 4,
#   '[ent.audiovisual_tv_season_number],[ent.audiovisual_tvseries_title],[ent.device_tv]': 3,
#   '[ent.audiovisual_genre],[ent.device_tv]': 3,
#   '[ent.audiovisual_sports_unit],[ent.device_tv]': 8,
#   '[ent.audiovisual_documental_title],[ent.device_tv]': 6,
#   '[ent.audiovisual_sports],[ent.device_tv]': 7,
#   '[ent.audiovisual_sports_unit],[ent.audiovisual_sports_team],[ent.device_tv]': 1,
#   '[ent.audiovisual_tvseries_title],[ent.device_tv]': 14,
#   '[ent.audiovisual_actor],[ent.device_tv]': 2,
#   '[ent.audiovisual_tvshow_title],[ent.device_tv]': 4,
#   '[ent.audiovisual_film_title],[ent.device_tv]': 5,
#   '[ent.audiovisual_tvseries_title],[ent.audiovisual_tv_season_number],[ent.audiovisual_tv_episode_number],[ent.device_tv]': 1,
#   '[ent.audiovisual_documental_title]': 1,
#   '[ent.audiovisual_film_title]': 1,
#   '[ent.audiovisual_tvseries_title]': 1,
#   '[ent.device_tv],[ent.audiovisual_film_title]': 1,
#   '[ent.device_tv],[ent.audiovisual_tvseries_title]': 1,
#   '[ent.audiovisual_tvseries_title],[ent.audiovisual_tv_episode_number],[ent.device_tv]': 1,
#   '[ent.audiovisual_subgenre],[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_actor],[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_actor],[ent.audiovisual_actor],[ent.device_tv]': 1,
#   '[ent.audiovisual_genre],[ent.audiovisual_director],[ent.device_tv]': 2,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_actor],[ent.device_tv]': 1,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_actor],[ent.audiovisual_actor],[ent.device_tv]': 1,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_director],[ent.device_tv]': 2,
#   '[ent.device_tv]': 7},
#  'intent.tv.question_time_loc': {'[ent.audiovisual_sports_unit],[ent.audiovisual_sports]': 16,
#   '[ent.audiovisual_sports_team]': 15,
#   '[ent.audiovisual_tvshow_title]': 37,
#   '[ent.audiovisual_sports_season]': 33,
#   '[ent.audiovisual_sports]': 13,
#   '[ent.audiovisual_sports_unit]': 13,
#   '[ent.audiovisual_sports_unit],[ent.audiovisual_sports_team]': 14,
#   '[ent.audiovisual_sports_team],[ent.audiovisual_sports_team]': 20,
#   '[ent.audiovisual_sports_unit],[ent.audiovisual_sports_season]': 17,
#   '[ent.audiovisual_tvseries_title]': 9,
#   '[ent.audiovisual_tv_episode_number],[ent.audiovisual_tvseries_title]': 1,
#   '[ent.audiovisual_sports_season],[ent.audiovisual_sports]': 2,
#   '[ent.audiovisual_sports_unit],[ent.time_instant]': 1,
#   '[ent.audiovisual_tvseries_title],[ent.device_tv]': 1,
#   '[ent.audiovisual_tv_season_number],[ent.audiovisual_tvseries_title],[ent.device_tv]': 1},
#  'intent.tv.search': {'[ent.audiovisual_actor]': 21,
#   '[ent.audiovisual_actor],[ent.audiovisual_actor]': 2,
#   '[ent.audiovisual_director]': 12,
#   '[ent.audiovisual_sports]': 4,
#   '[ent.audiovisual_genre]': 10,
#   '[ent.audiovisual_genre],[ent.audiovisual_subgenre]': 7,
#   '[ent.audiovisual_genre],[ent.audiovisual_director]': 14,
#   '[ent.audiovisual_genre],[ent.audiovisual_actor]': 16,
#   '[ent.audiovisual_genre],[ent.audiovisual_actor],[ent.audiovisual_actor]': 5,
#   '[ent.audiovisual_tvseries_title]': 7,
#   '[ent.audiovisual_sports_season]': 5,
#   '[ent.audiovisual_sports_unit]': 9,
#   '[ent.audiovisual_sports_unit],[ent.audiovisual_sports]': 2,
#   '[ent.audiovisual_sports_unit],[ent.audiovisual_sports_season]': 5,
#   '[ent.audiovisual_tv_episode_number],[ent.audiovisual_tv_season_number],[ent.audiovisual_tvseries_title]': 3,
#   '[ent.audiovisual_tv_season_number],[ent.audiovisual_tvseries_title]': 2,
#   '[ent.audiovisual_documental_title]': 5,
#   '[ent.audiovisual_subgenre]': 4,
#   '[ent.audiovisual_tvshow_title]': 6,
#   '[ent.audiovisual_film_title]': 6,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_director]': 6,
#   '[ent.audiovisual_tvseries_title],[ent.audiovisual_tv_episode_number]': 2,
#   '[ent.audiovisual_tvseries_title],[ent.audiovisual_tv_season_number],[ent.audiovisual_tv_episode_number]': 3,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_actor]': 2,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_actor],[ent.audiovisual_actor]': 3},
#  'intent.tv.search_similar': {'[ent.audiovisual_subgenre],[ent.audiovisual_film_title]': 14,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_tvseries_title]': 15,
#   '[ent.audiovisual_subgenre],[ent.audiovisual_tvshow_title]': 15,
#   '[ent.audiovisual_film_title]': 16,
#   '[ent.audiovisual_tvseries_title]': 14,
#   '[ent.audiovisual_tvshow_title]': 10,
#   '[ent.audiovisual_actor],[ent.audiovisual_tvshow_title]': 2,
#   '[ent.audiovisual_director],[ent.audiovisual_film_title]': 3,
#   '[ent.audiovisual_genre],[ent.audiovisual_tvseries_title]': 17,
#   '[ent.audiovisual_genre],[ent.audiovisual_tvshow_title]': 14,
#   '[ent.audiovisual_genre],[ent.audiovisual_documental_title]': 18,
#   '[ent.audiovisual_genre],[ent.audiovisual_film_title]': 12,
#   '[ent.audiovisual_documental_title]': 23},
#  'None': {}}
