# %%
import json
import re

# %%
a = ["juan", "pedro", "maria"]
b = ["pedro", "maria", "pablo"]

# %%
c = set(a) & set(b)

# %%
for i in c:
    x = input(i + " Está en ambos conjuntos. Dónde querés dejarlo? \n A) Dir B) Act")
    
    if x == "A":
        b.remove(i)
    else:
        a.remove(i)
        
p
# Out:
# pedro Está en ambos conjuntos. Dónde querés dejarlo?
#  A) Dir B) Act A
# maria Está en ambos conjuntos. Dónde querés dejarlo?
#  A) Dir B) Act B

# %%
print(a)
# Out:
# ['juan', 'pedro']

# %%
print(b)
# Out:
# ['maria', 'pablo']

# %%
import json

# %%
actors = "/home/fernando/aura-nlpdata-ar/data/es-ar/mplay/_BUILD_SDICT/sources/AUTH/#mplay_actors.ent.json" 
directors = "/home/fernando/aura-nlpdata-ar/data/es-ar/mplay/_BUILD_SDICT/sources/AUTH/#mplay_directors.ent.json"

# %%
with open(actors) as f:
    actor = json.load(f)


with open(directors) as f2:
    director = json.load(f2)

# %%
lact = actor['ent.audiovisual_actor']
ldir = director['ent.audiovisual_director']

# %%
for
# Out:
# [["'Maravilla' Martínez", "Sergio 'Maravilla' Martínez"],
#  'A. Martínez',
#  'A. Murat Özgen',
#  'A.C. Peterson',
#  'A.D. Miles',
#  'A.J. Buckley',
#  'A.J. Cook',
#  'A.J. Langer',
#  'A.J. Locascio',
#  'Aabhas Yadav',
#  'Aaden Gosselin',
#  'Aaliyah',
#  'Aaliyah Brown',
#  ['Aaliyah Hadid', 'Hadid Aaliyah'],
#  ['Aaliyah Love', 'Love Aaliyah'],
#  'Aamina Sheikh',
#  'Aamir Bashir',
#  'Aamir Khan',
#  'Aarif Rahman',
#  'Aaron Abrams',
#  'Aaron Ashmore',
#  'Aaron Brumfield',
#  'Aaron Conley',
#  'Aaron Douglas',
#  'Aaron Dugger',
#  'Aaron Eckhart',
#  'Aaron Fotheringham',
#  'Aaron Hale',
#  'Aaron Hill',
#  'Aaron Himelstein',
#  'Aaron Jakubenko',
#  'Aaron Jeffery',
#  'Aaron Johnson',
#  'Aaron Kwok',
#  'Aaron L. Mcgrath',
#  'Aaron Lee',
#  'Aaron Marsden',
#  'Aaron Marshall',
#  'Aaron Martin',
#  'Aaron Mccusker',
#  'Aaron Michael Drozin',
#  'Aaron Moten',
#  "Aaron O'Connell",
#  'Aaron Paul',
#  'Aaron Pearl',
#  'Aaron Poole',
#  'Aaron Pruner',
# ...
