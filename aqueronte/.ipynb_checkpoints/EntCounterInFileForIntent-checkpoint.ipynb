# %%
import json
import re

# %%
with open("/home/fernando/Escritorio/mios/divina_comedia/aqueronte/resources/luis_trainingset.tv.tef.json") as f:
    archivo = json.load(f)

# %%
def get_entidad(file):
        entidad = re.compile(r'\[.+?\]')
        
        return entidad


def find_entities(dic):
    #entidad = get_entidad(dic)
    entidadRe = re.compile(r'\[.+?\]')
    entidades = []
    out = {}
    
    for intent in dic['intents'].keys():
        out[intent] = []
        
        for utterance in dic['intents'][intent]:
            ent = re.findall(entidad,utterance)
            
            if len(ent) >= 1:
                #entidades.append(intent + ", " + str(tuple(ent))) #Append devuelve lista de lista   
                out[intent].append(ent)
            
    return out


def count_entities(file):
    
    entidades = find_entities(file)
    cuenta = []
    
    #return {i:entidades.count(i) for i in entidades}
    return entidades

# %%
count_entities(archivo)
# Out:
# {'intent.tv.content_get_info': [['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_instant]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.device_tv]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_instant]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.device_tv]'],
#   ['[ent.device_tv]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.time_instant]'],
#   ['[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.time_instant]', '[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.device_tv]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_instant]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.device_tv]', '[ent.time_instant]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.time_instant]', '[ent.audiovisual_channel]'],
#   ['[ent.time_instant]', '[ent.audiovisual_channel]'],
#   ['[ent.time_instant]', '[ent.audiovisual_sports_unit]'],
#   ['[ent.time_instant]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]', '[ent.audiovisual_genre]'],
#   ['[ent.time_instant]'],
#   ['[ent.time_instant]'],
#   ['[ent.time_instant]'],
#   ['[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.time_instant]'],
#   ['[ent.time_interval]',
#    '[ent.time_instant]',
#    '[ent.audiovisual_sports_unit]'],
#   ['[ent.time_interval]', '[ent.time_instant]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_interval]', '[ent.audiovisual_genre]'],
#   ['[ent.time_interval]', '[ent.audiovisual_sports_unit]'],
#   ['[ent.time_interval]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]'],
#   ['[ent.time_interval]'],
#   ['[ent.device_tv]', '[ent.time_instant]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_instant]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_interval]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.device_tv]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.device_tv]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.device_tv]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]', '[ent.time_interval]'],
#   ['[ent.audiovisual_genre]', '[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.time_interval]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.time_instant]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_channel]',
#    '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.time_instant]',
#    '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_instant]'],
#   ['[ent.audiovisual_subgenre]', '[ent.time_interval]'],
#   ['[ent.time_instant]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.time_instant]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.device_tv]', '[ent.time_instant]'],
#   ['[ent.device_tv]', '[ent.time_interval]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.device_tv]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]', '[ent.time_instant]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.time_interval]', '[ent.time_instant]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.device_tv]', '[ent.time_instant]'],
#   ['[ent.time_instant]', '[ent.audiovisual_channel]'],
#   ['[ent.time_interval]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.time_instant]'],
#   ['[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.time_interval]', '[ent.device_tv]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]'],
#   ['[ent.time_interval]', '[ent.audiovisual_channel]'],
#   ['[ent.audiovisual_channel]', '[ent.time_instant]'],
#   ['[ent.time_instant]'],
#   ['[ent.audiovisual_channel]', '[ent.time_instant]'],
#   ['[ent.audiovisual_channel]', '[ent.time_interval]']],
#  'intent.tv.display': [['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_season]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports_team]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_actor]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_season]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvshow_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_film_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tv_episode_number]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_film_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_film_title]', '[ent.device_tv]'],
#   ['[ent.device_tv]', '[ent.audiovisual_film_title]'],
#   ['[ent.device_tv]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_film_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_film_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_season]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_tv_episode_number]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvshow_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvshow_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_actor]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_documental_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvshow_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]', '[ent.device_tv]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]', '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_director]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_director]',
#    '[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.device_tv]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_season]', '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.device_tv]']],
#  'intent.tv.question_time_loc': [['[ent.audiovisual_sports_unit]',
#    '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tv_episode_number]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_season]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.time_instant]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.device_tv]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]',
#    '[ent.device_tv]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]'],
#   ['[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]']],
#  'intent.tv.search': [['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_episode_number]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_sports]'],
#   ['[ent.audiovisual_sports_season]'],
#   ['[ent.audiovisual_sports_unit]'],
#   ['[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_episode_number]'],
#   ['[ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tv_episode_number]'],
#   ['[ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tv_episode_number]'],
#   ['[ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_tv_season_number]',
#    '[ent.audiovisual_tv_episode_number]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_genre]'],
#   ['[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_director]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_actor]']],
#  'intent.tv.search_similar': [['[ent.audiovisual_subgenre]',
#    '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_actor]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_director]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_director]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_actor]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_director]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvseries_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_documental_title]'],
#   ['[ent.audiovisual_film_title]'],
#   ['[ent.audiovisual_tvshow_title]'],
#   ['[ent.audiovisual_documental_title]']],
#  'None': []}

# %%
entidadRe = re.compile(r'\[.+?\]')
entidades = []
out = {}

for intent in dic['intents'].keys():
    out[intent] = []

    for utterance in dic['intents'][intent]:
        ent = re.findall(entidad,utterance)

        if len(ent) >= 1:
            #entidades.append(intent + ", " + str(tuple(ent))) #Append devuelve lista de lista   
            out[intent].append(ent)
# Out:
# {'metadata': {'name': 'AURA Movistar Tv Arg',
#   'version': '1.0.0.0',
#   'date': '2019-09-19',
#   'domain': 'domain.tv'},
#  'intents': {'intent.tv.content_get_info': ['Algo divertido para mirar en [ent.audiovisual_channel]',
#    'En [ent.audiovisual_channel] [ent.time_interval] ¿qué darán?',
#    'En [ent.audiovisual_channel] ¿qué pasan?',
#    'Please ¿qué [ent.audiovisual_subgenre] están pasando en [ent.audiovisual_channel] [ent.time_instant]?',
#    'Please ¿qué [ent.audiovisual_subgenre] puedo mirar por [ent.audiovisual_channel] [ent.time_instant]?',
#    'Plis [ent.time_interval] ¿qué [ent.audiovisual_genre] pasarán?',
#    'Plis en la [ent.device_tv] ¿qué tienen?',
#    'Por [ent.audiovisual_channel] ¿qué estarán pasando?',
#    'Por favor [ent.audiovisual_genre] [ent.audiovisual_subgenre] [ent.time_interval]',
#    'Por favor [ent.audiovisual_genre] [ent.time_instant]',
#    'Por favor [ent.audiovisual_genre] [ent.time_interval] en la [ent.device_tv]',
#    'Por favor [ent.time_interval] en [ent.audiovisual_channel] ¿qué puedo ver?',
#    'Por favor en [ent.audiovisual_channel] ¿qué están dando?',
#    'Por favor por [ent.audiovisual_channel] [ent.time_interval] ¿qué darán?',
#    'Por favor ¿qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] van a pasar [ent.time_instant] en [ent.audiovisual_channel]?',
#    'Por favor ¿qué [ent.audiovisual_genre] están televisando en [ent.audiovisual_channel] [ent.time_interval]?',
#    'Por favor ¿qué [ent.audiovisual_genre] van a transmitir en la [ent.device_tv]?',
#    'Por favor ¿qué [ent.audiovisual_subgenre] están transmitiendo en la [ent.device_tv]?',
#    'Por favor ¿qué están dando?',
#    'Por favor ¿qué hay en la [ent.device_tv] [ent.time_interval]?',
#    'Por favor ¿qué pasan por [ent.audiovisual_channel] [ent.time_interval]?',
#    'Por favor ¿qué van a pasar [ent.time_instant]?',
#    'Por favor ¿qué van a pasar [ent.time_interval] en la [ent.device_tv]?',
#    'Por favor ¿qué ver en [ent.audiovisual_channel]?',
#    'Porfa [ent.time_instant] ¿qué [ent.audiovisual_genre] podré mirar?',
#    'Porfis en [ent.audiovisual_channel] ¿qué puedo ver?',
#    'Porfis por [ent.audiovisual_channel] [ent.time_interval] ¿qué puedo ver?',
#    'Porfis ¿qué tienen en la [ent.device_tv] [ent.time_interval]?',
#    'Programación [ent.audiovisual_channel]',
#    'Programación [ent.audiovisual_channel] [ent.time_instant]',
#    'Programación [ent.audiovisual_channel] [ent.time_interval]',
#    'Programación [ent.audiovisual_channel] para [ent.time_interval]',
#    'Programación de [ent.audiovisual_channel] [ent.time_interval]',
#    'Quiero algo lindo para ver en [ent.audiovisual_channel]',
#    'Qué [ent.audiovisual_genre] están pasando en [ent.audiovisual_channel]',
#    'Qué [ent.audiovisual_genre] están pasando por [ent.audiovisual_channel]',
#    'Qué están pasando en [ent.audiovisual_channel]',
#    'Qué están pasando por [ent.audiovisual_channel]',
#    'Qué pasan por [ent.audiovisual_channel]',
#    'Ver la programación de [ent.audiovisual_channel]',
#    'Xfa [ent.audiovisual_genre] por [ent.audiovisual_channel]',
#    'Xfa ¿qué tienen en la [ent.device_tv] [ent.time_instant]?',
#    '[ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] [ent.audiovisual_subgenre] [ent.time_instant]',
#    '[ent.audiovisual_genre] [ent.audiovisual_subgenre] para [ent.time_instant]',
#    '[ent.audiovisual_genre] [ent.audiovisual_subgenre] por [ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] [ent.time_instant]',
#    '[ent.audiovisual_genre] [ent.time_instant] en la [ent.device_tv]',
#    '[ent.audiovisual_genre] [ent.time_instant] por favor',
#    '[ent.audiovisual_genre] [ent.time_interval]',
#    '[ent.audiovisual_genre] [ent.time_interval] porfavor',
#    '[ent.audiovisual_genre] de [ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] de [ent.audiovisual_channel] para ver',
#    '[ent.audiovisual_genre] en [ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] para mirar en [ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] para ver en [ent.audiovisual_channel]',
#    '[ent.audiovisual_genre] que den en [ent.audiovisual_channel]',
#    '[ent.time_instant] [ent.time_interval] [ent.audiovisual_channel]',
#    '[ent.time_instant] [ent.time_interval] ¿qué [ent.audiovisual_genre] están televisando?',
#    '[ent.time_instant] [ent.time_interval] ¿qué [ent.audiovisual_genre] habrá?',
#    '[ent.time_instant] [ent.time_interval] ¿qué [ent.audiovisual_genre] transmitirán?',
#    '[ent.time_instant] en la [ent.device_tv] ¿qué van a dar?',
#    '[ent.time_instant] en la [ent.device_tv] ¿qué van a pasar?',
#    '[ent.time_instant] por [ent.audiovisual_channel] ¿qué darán?',
#    '[ent.time_instant] por [ent.audiovisual_channel] ¿qué van a dar?',
#    '[ent.time_instant] ¿están pasando [ent.audiovisual_sports_unit]?',
#    '[ent.time_instant] ¿qué [ent.audiovisual_genre] pasan?',
#    '[ent.time_instant] ¿qué [ent.audiovisual_genre] podría mirar?',
#    '[ent.time_instant] ¿qué [ent.audiovisual_genre] van a transmitir?',
#    '[ent.time_instant] ¿qué [ent.audiovisual_genre] veo?',
#    '[ent.time_instant] ¿qué hay?',
#    '[ent.time_instant] ¿qué pasan?',
#    '[ent.time_instant] ¿qué tienen?',
#    '[ent.time_instant] ¿qué van a dar en la [ent.device_tv]?',
#    '[ent.time_instant] ¿qué van a dar?',
#    '[ent.time_interval] [ent.time_instant] ¿qué [ent.audiovisual_sports_unit] dan?',
#    '[ent.time_interval] [ent.time_instant] ¿qué dan?',
#    '[ent.time_interval] en [ent.audiovisual_channel]',
#    '[ent.time_interval] por [ent.audiovisual_channel] ¿qué hay?',
#    '[ent.time_interval] por [ent.audiovisual_channel] ¿qué van a dar?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_genre] están dando?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_genre] están televisando?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_genre] podré ver?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_genre] televisan?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_genre] televisarán?',
#    '[ent.time_interval] ¿qué [ent.audiovisual_sports_unit] dan?',
#    '[ent.time_interval] ¿qué dan?',
#    '[ent.time_interval] ¿qué estarán pasando en [ent.audiovisual_channel]?',
#    '[ent.time_interval] ¿qué hay?',
#    '[ent.time_interval] ¿qué van a dar?',
#    '¿En la [ent.device_tv] qué hay [ent.time_instant]?',
#    '¿Hay algo lindo en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] están transmitiendo en [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] hay [ent.time_instant] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] pasan por [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] pasarán en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] podré mirar [ent.time_interval] en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] podría ver en [ent.audiovisual_channel] [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] podría ver en la [ent.device_tv] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] transmitirán en la [ent.device_tv] [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] van a dar [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] van a pasar en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] van a televisar en la [ent.device_tv] [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] [ent.audiovisual_subgenre] van a transmitir por [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_genre] dan [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] darán [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] darán en la [ent.device_tv] [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] están transmitiendo por [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_genre] miro [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] pasan en [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] podré ver [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_genre] podría ver [ent.time_instant] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] puedo ver [ent.time_interval] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] puedo ver en [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] transmiten en la [ent.device_tv] [ent.time_interval]?',
#    '¿Qué [ent.audiovisual_genre] transmitirán [ent.time_instant] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] van a transmitir [ent.time_interval] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] veo [ent.time_interval] en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_subgenre] están dando [ent.time_instant] en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_subgenre] están dando [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] están televisando [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] están transmitiendo [ent.time_instant] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] habrá [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] habrá en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] hay en [ent.audiovisual_channel] [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] miro [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] pasan [ent.time_instant] por [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_subgenre] podré ver en [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_subgenre] puedo mirar por [ent.audiovisual_channel]?',
#    '¿Qué [ent.audiovisual_subgenre] televisan [ent.time_interval] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] van a dar [ent.time_instant] en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] van a pasar en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] van a televisar [ent.time_instant]?',
#    '¿Qué [ent.audiovisual_subgenre] veo [ent.time_interval]?',
#    '¿Qué dan [ent.time_instant] [ent.time_interval]?',
#    '¿Qué dan en [ent.audiovisual_channel]?',
#    '¿Qué darán en [ent.audiovisual_channel]?',
#    '¿Qué estarán pasando [ent.time_instant]?',
#    '¿Qué estarán pasando en [ent.audiovisual_channel]?',
#    '¿Qué estarán pasando en el [ent.device_tv] [ent.time_instant]?',
#    '¿Qué estarán pasando en la [ent.device_tv] [ent.time_interval]?',
#    '¿Qué estarán pasando por favor?',
#    '¿Qué están dando [ent.time_interval] en [ent.audiovisual_channel]?',
#    '¿Qué están dando en la [ent.device_tv] [ent.time_interval]?',
#    '¿Qué están dando por [ent.audiovisual_channel] [ent.time_instant]?',
#    '¿Qué están dando por [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué están dando?',
#    '¿Qué hay en [ent.audiovisual_channel]',
#    '¿Qué hay en [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué pasan [ent.time_interval] [ent.time_instant]?',
#    '¿Qué pasan [ent.time_interval] en [ent.audiovisual_channel]?',
#    '¿Qué pasan [ent.time_interval] en la [ent.device_tv]?',
#    '¿Qué pasan [ent.time_interval]?',
#    '¿Qué pasan en [ent.audiovisual_channel]?',
#    '¿Qué pasan por [ent.audiovisual_channel] [ent.time_interval] por favor?',
#    '¿Qué pasan por [ent.audiovisual_channel]?',
#    '¿Qué pasarán [ent.time_interval]?',
#    '¿Qué pasarán en [ent.audiovisual_channel]?',
#    '¿Qué pasarán en la [ent.device_tv] [ent.time_instant]?',
#    '¿Qué puedo ver [ent.time_instant] en [ent.audiovisual_channel] plis?',
#    '¿Qué puedo ver [ent.time_interval]?',
#    '¿Qué puedo ver por [ent.audiovisual_channel]?',
#    '¿Qué tienen [ent.time_instant] porfa?',
#    '¿Qué tienen en [ent.audiovisual_channel]?',
#    '¿Qué tienen por [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué van a dar [ent.time_interval] en la [ent.device_tv]?',
#    '¿Qué van a dar en [ent.audiovisual_channel] [ent.time_interval]?',
#    '¿Qué van a pasar [ent.time_interval] en [ent.audiovisual_channel]?',
#    '¿Qué van a pasar en [ent.audiovisual_channel] [ent.time_instant]?',
#    '¿Qué ver [ent.time_instant]?',
#    '¿Qué ver en [ent.audiovisual_channel] [ent.time_instant]?',
#    '¿Qué ver en [ent.audiovisual_channel] [ent.time_interval]?'],
#   'intent.tv.display': ['El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] en el [ent.device_tv]',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] en la [ent.device_tv]',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] mostralo por la [ent.device_tv]',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] pasalo a la [ent.device_tv]',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] ponelo en la [ent.device_tv]',
#    'El [ent.audiovisual_tv_episode_number] de la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] en el [ent.device_tv]',
#    'La [ent.audiovisual_sports_season] en el [ent.device_tv]',
#    'La [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] en el [ent.device_tv]',
#    'Mandá la [ent.audiovisual_genre] a la [ent.device_tv] xfa',
#    'Mandá la [ent.audiovisual_genre] al [ent.device_tv] xfa',
#    'Mandá la [ent.audiovisual_sports_unit] en el [ent.device_tv] xfa',
#    'Mostrar [ent.audiovisual_documental_title] en la [ent.device_tv]',
#    'Pasame [ent.audiovisual_sports] en el [ent.device_tv]',
#    'Pasame [ent.audiovisual_sports] por la [ent.device_tv]',
#    'Pasame [ent.audiovisual_sports] por la [ent.device_tv]?',
#    'Pasame el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team] por la [ent.device_tv]',
#    'Pasar [ent.audiovisual_tvseries_title] en la [ent.device_tv]',
#    'Pasar algo que protagoniza [ent.audiovisual_actor] en el [ent.device_tv]',
#    'Pasar la [ent.audiovisual_sports_season] en la [ent.device_tv] por favor',
#    'Pasar una [ent.audiovisual_genre] a la [ent.device_tv]',
#    'Plis [ent.audiovisual_tvseries_title] en el [ent.device_tv]',
#    'Poneme la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] en la [ent.device_tv]',
#    'Poner los [ent.audiovisual_sports_unit] en el [ent.device_tv]',
#    'Por favor [ent.audiovisual_tvseries_title] en la [ent.device_tv]',
#    'Por favor [ent.audiovisual_tvshow_title] en la [ent.device_tv]',
#    'Por favor mostrame [ent.audiovisual_documental_title] en el [ent.device_tv]',
#    'Por favor quiero [ent.audiovisual_film_title] en el [ent.device_tv]',
#    'Por favor ¿me reproducís la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] en la [ent.device_tv]?',
#    'Reproducime [ent.audiovisual_tvseries_title] [ent.audiovisual_tv_season_number] [ent.audiovisual_tv_episode_number] en el [ent.device_tv]',
#    'Reproducir [ent.audiovisual_documental_title]',
#    'Reproducir [ent.audiovisual_documental_title] por la [ent.device_tv]',
#    'Reproducir [ent.audiovisual_film_title]',
#    'Reproducir [ent.audiovisual_film_title] por la [ent.device_tv]',
#    'Reproducir [ent.audiovisual_tvseries_title]',
#    'Reproducir [ent.audiovisual_tvseries_title] por la [ent.device_tv]',
#    'Ver [ent.audiovisual_film_title] en el [ent.device_tv]',
#    'Ver en el [ent.device_tv] [ent.audiovisual_film_title]',
#    'Ver en la [ent.device_tv] [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_documental_title] en el [ent.device_tv]',
#    '[ent.audiovisual_documental_title] en la [ent.device_tv] por favor',
#    '[ent.audiovisual_film_title] en la [ent.device_tv]',
#    '[ent.audiovisual_film_title] en la [ent.device_tv] por favor',
#    '[ent.audiovisual_sports] en el [ent.device_tv]',
#    '[ent.audiovisual_sports] en la [ent.device_tv]',
#    '[ent.audiovisual_sports_season] en la [ent.device_tv]',
#    '[ent.audiovisual_sports_unit] en el [ent.device_tv]',
#    '[ent.audiovisual_tvseries_title] [ent.audiovisual_tv_episode_number] en la [ent.device_tv]',
#    '[ent.audiovisual_tvseries_title] a la [ent.device_tv]',
#    '[ent.audiovisual_tvseries_title] en el [ent.device_tv] por favor',
#    '[ent.audiovisual_tvseries_title] en la [ent.device_tv]',
#    '[ent.audiovisual_tvseries_title] mandalo a la [ent.device_tv]',
#    '[ent.audiovisual_tvseries_title] pasalo por la [ent.device_tv]',
#    '[ent.audiovisual_tvshow_title] en el [ent.device_tv]',
#    '[ent.audiovisual_tvshow_title] en la [ent.device_tv]',
#    '¿Me pasás [ent.audiovisual_sports] en el [ent.device_tv]?',
#    '¿Me pasás el [ent.audiovisual_sports_unit] en el [ent.device_tv]?',
#    '¿Me podes poner [ent.audiovisual_tvseries_title] en el [ent.device_tv]?',
#    '¿Me ponés [ent.audiovisual_sports] en la [ent.device_tv]?',
#    '¿Me ponés [ent.audiovisual_sports_unit] en la [ent.device_tv]?',
#    '¿Me ponés [ent.audiovisual_tvseries_title] en el [ent.device_tv]?',
#    '¿Me ponés a [ent.audiovisual_actor] en el [ent.device_tv]?',
#    '¿Me ponés algo [ent.audiovisual_subgenre] en la [ent.device_tv]?',
#    '¿Me ponés la [ent.audiovisual_sports_unit] en el [ent.device_tv] xfa?',
#    '¿Me reproducís el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] en la [ent.device_tv]?',
#    '¿Me reproducís la [ent.audiovisual_sports_unit] en el [ent.device_tv]?',
#    '¿Podes mandar [ent.audiovisual_tvseries_title] al [ent.device_tv]?',
#    '¿Podes mostrar [ent.audiovisual_documental_title] en la [ent.device_tv]?',
#    '¿Podés mostrar [ent.audiovisual_tvseries_title] en la [ent.device_tv] porfavor?',
#    '¿Podés pasar [ent.audiovisual_tvshow_title] en el [ent.device_tv] por favor?',
#    '¿Qué [ent.audiovisual_genre] con [ent.audiovisual_actor] tenés en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] con [ent.audiovisual_actor] y [ent.audiovisual_actor] puedo ver en el [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] cuya directora es [ent.audiovisual_director] hay en el [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director] hay en el [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] tenés en el [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] y con [ent.audiovisual_actor] hay para ver en el [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] cuyo director es [ent.audiovisual_director] hay para ver en la [ent.device_tv]?',
#    '¿Qué [ent.audiovisual_subgenre] dirigida por [ent.audiovisual_director] tenés en el [ent.device_tv]?',
#    '¿Qué hay en el [ent.device_tv]?',
#    '¿Qué hay en la [ent.device_tv]?',
#    '¿Qué hay para ver en el [ent.device_tv]?',
#    '¿Qué puedo mirar en el [ent.device_tv]?',
#    '¿Qué puedo mirar en la [ent.device_tv] por favor?',
#    '¿Qué tenés para ver en el [ent.device_tv]?',
#    '¿Qué tenés para ver en la [ent.device_tv]?',
#    '¿Reproducís [ent.audiovisual_tvseries_title] en el [ent.device_tv]?',
#    '¿Reproducís la [ent.audiovisual_sports_season] en la [ent.device_tv]?',
#    '¿Reproducís la [ent.audiovisual_sports_unit] en la [ent.device_tv]?'],
#   'intent.tv.question_time_loc': ['A qué hora juegan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    'Canal [ent.audiovisual_sports_team]',
#    'Canal [ent.audiovisual_tvshow_title]',
#    'Canal de [ent.audiovisual_sports_team]',
#    'Canal de [ent.audiovisual_tvshow_title]',
#    'Canal de la [ent.audiovisual_sports_season]',
#    'Canal del [ent.audiovisual_sports_season]',
#    'Canal y hora [ent.audiovisual_sports_team]',
#    'Canal y hora de [ent.audiovisual_sports]',
#    'Canal y hora de [ent.audiovisual_sports_team]',
#    'Canal y hora de [ent.audiovisual_sports_team] por favor',
#    'Canal y hora de la [ent.audiovisual_sports_season]',
#    'Canal y hora del [ent.audiovisual_sports_unit]',
#    'Canal y hora del [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]',
#    'Canal y horario de [ent.audiovisual_sports]',
#    'Canal y horario de [ent.audiovisual_tvshow_title]',
#    'Canal y horario de la [ent.audiovisual_sports_season]',
#    'Canal y horario del [ent.audiovisual_sports_season]',
#    'Canal y horario del [ent.audiovisual_sports_unit]',
#    'Dónde juega [ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team] plis',
#    'El [ent.audiovisual_sports_season] canal',
#    'El [ent.audiovisual_sports_season] canal y hora',
#    'El [ent.audiovisual_sports_season] en qué horario y en qué canal se juega',
#    'El [ent.audiovisual_sports_season] hora y canal',
#    'El [ent.audiovisual_sports_season] horario porfavor',
#    'El [ent.audiovisual_sports_unit] canal y hora',
#    'El [ent.audiovisual_sports_unit] canal y horario porfis',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] a qué hora pasan xfa',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team] a qué hora lo pasan',
#    'El [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season] a dónde emiten',
#    'El [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season] en qué horario emiten',
#    'El [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season] en qué horario y en qué canal es',
#    'El [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season] quisiera saber a qué hora transmiten',
#    'El [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season] en dónde es',
#    'El [ent.audiovisual_sports_unit] hora y canal',
#    'Hora [ent.audiovisual_sports_season]',
#    'Hora [ent.audiovisual_tvseries_title]',
#    'Hora [ent.audiovisual_tvshow_title]',
#    'Hora [ent.audiovisual_tvshow_title] por favor',
#    'Hora de [ent.audiovisual_sports_team]',
#    'Hora de [ent.audiovisual_tvseries_title]',
#    'Hora de [ent.audiovisual_tvshow_title]',
#    'Hora de la [ent.audiovisual_sports_season]',
#    'Hora del [ent.audiovisual_sports_unit]',
#    'Hora del [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]',
#    'Hora del [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]',
#    'Hora y canal [ent.audiovisual_sports_team]',
#    'Hora y canal [ent.audiovisual_tvshow_title]',
#    'Hora y canal [ent.audiovisual_tvshow_title] por favor',
#    'Hora y canal el [ent.audiovisual_sports_unit]',
#    'Horario de [ent.audiovisual_tvseries_title]',
#    'Horario de [ent.audiovisual_tvshow_title]',
#    'Horario y canal de [ent.audiovisual_sports_team]',
#    'Horario y canal de la [ent.audiovisual_sports_season]',
#    'Horario y canal el [ent.audiovisual_sports_unit]',
#    'La [ent.audiovisual_sports_season] canal y hora',
#    'La [ent.audiovisual_sports_season] hora',
#    'La [ent.audiovisual_sports_season] horario',
#    'La [ent.audiovisual_sports_season] horario y canal',
#    'La [ent.audiovisual_sports_unit] canal y horario',
#    'La [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team], me gustaría saber dónde es',
#    'La [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season], ¿adónde y a qué hora puedo verlo?',
#    'Los [ent.audiovisual_sports_unit] canal y hora xfa',
#    'Los [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season] la hora en la que es',
#    'Please horario y canal el [ent.audiovisual_sports_unit]',
#    'Plis, ¿a qué hora juega [ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team]?',
#    'Por favor [ent.audiovisual_sports_team] hora',
#    'Por favor [ent.audiovisual_tvshow_title] canal y hora',
#    'Por favor canal y hora de la [ent.audiovisual_sports_season]',
#    'Por favor el [ent.audiovisual_sports_season] horario y canal',
#    'Por favor el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team], ¿a qué hora y en qué canal puedo verlo?',
#    'Por favor, ¿[ent.audiovisual_sports_team] versus [ent.audiovisual_sports_team] a dónde juega?',
#    'Por favor, ¿[ent.audiovisual_sports_team] y [ent.audiovisual_sports_team] en qué hora y en qué canal juegan?',
#    'Por favor, ¿a qué hora juega [ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team]?',
#    'Por favor, ¿cuándo retransmiten [ent.audiovisual_tvshow_title]?',
#    'Por favor, ¿en qué horario y a dónde es el [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]?',
#    'Por favor, ¿en qué horario y dónde juegan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    'Por favor, ¿en qué horario y en qué canal puedo ver [ent.audiovisual_tvshow_title]?',
#    'Por favor, ¿la [ent.audiovisual_sports_season] en qué canal y a qué hora se juega?',
#    'Porfa [ent.audiovisual_sports_team] hora y canal',
#    'Porfis, ¿en qué horario se juega el [ent.audiovisual_sports_season]?',
#    'Quiero saber a qué hora es el [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]',
#    'Quiero saber a qué hora y a dónde es el [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]',
#    'Quiero saber a qué hora y dónde pasan el programa de [ent.audiovisual_tvshow_title]',
#    'Quiero saber a qué hora y por dónde juegan [ent.audiovisual_sports]',
#    'Quiero saber cuándo puedo ver [ent.audiovisual_sports]',
#    'Quiero saber cuándo y en qué canal se juega el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    'Quiero saber en dónde es el [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]',
#    'Quiero saber en qué canal se juega la [ent.audiovisual_sports_season]',
#    'Quiero saber en qué hora juegan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    'Quiero saber en qué horario dan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    '[ent.audiovisual_sports] canal',
#    '[ent.audiovisual_sports] hora y canal',
#    '[ent.audiovisual_sports] horario',
#    '[ent.audiovisual_sports_team] canal y hora',
#    '[ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team] canal y hora',
#    '[ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team] hora y canal',
#    '[ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team] quiero saber a dónde juega',
#    '[ent.audiovisual_sports_team] hora por favor',
#    '[ent.audiovisual_sports_team] hora y canal',
#    '[ent.audiovisual_sports_team] hora y canal por favor',
#    '[ent.audiovisual_sports_team] horario y canal',
#    '[ent.audiovisual_sports_team] vs [ent.audiovisual_sports_team] canal y hora',
#    '[ent.audiovisual_sports_team] vs [ent.audiovisual_sports_team] hora',
#    '[ent.audiovisual_sports_team] vs [ent.audiovisual_sports_team] horario',
#    '[ent.audiovisual_sports_team] vs [ent.audiovisual_sports_team], ¿a qué hora y adónde juega?',
#    '[ent.audiovisual_sports_team] y [ent.audiovisual_sports_team] canal',
#    '[ent.audiovisual_sports_team] y [ent.audiovisual_sports_team] canal y horario por favor',
#    '[ent.audiovisual_sports_team] y [ent.audiovisual_sports_team] cuándo juegan',
#    '[ent.audiovisual_sports_team] y [ent.audiovisual_sports_team] en qué hora juegan',
#    '[ent.audiovisual_tvshow_title] a qué hora lo dan',
#    '[ent.audiovisual_tvshow_title] canal porfavor',
#    '[ent.audiovisual_tvshow_title] canal y hora',
#    '[ent.audiovisual_tvshow_title] canal y horario',
#    '[ent.audiovisual_tvshow_title] hora y canal',
#    '[ent.audiovisual_tvshow_title] horario',
#    '[ent.audiovisual_tvshow_title] horario por favor',
#    '[ent.audiovisual_tvshow_title] horario y canal',
#    '¿A dónde y a qué hora juegan [ent.audiovisual_sports] porfa?',
#    '¿A dónde y en qué horario juegan [ent.audiovisual_sports] porfa?',
#    '¿A dónde y en qué horario juegan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿A que hora pasan el [ent.audiovisual_tv_episode_number] de [ent.audiovisual_tvseries_title]?',
#    '¿A qué hora [ent.audiovisual_tvseries_title]',
#    '¿A qué hora [ent.audiovisual_tvshow_title]',
#    '¿A qué hora dan [ent.audiovisual_tvshow_title]?',
#    '¿A qué hora dan el programa de [ent.audiovisual_tvshow_title] por favor?',
#    '¿A qué hora dan la [ent.audiovisual_sports_season] de [ent.audiovisual_sports]?',
#    '¿A qué hora pasan el [ent.audiovisual_sports_season] de [ent.audiovisual_sports]?',
#    '¿A qué hora pasan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿A qué hora pasan el programa de [ent.audiovisual_tvshow_title]?',
#    '¿A qué hora se juega la [ent.audiovisual_sports_season]?',
#    '¿A qué hora transmiten el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿A qué hora y a dónde pasan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿A qué hora y adónde es el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿A qué hora y adónde juegan [ent.audiovisual_sports_team] y [ent.audiovisual_sports_team]?',
#    '¿A qué hora y adónde juegan el [ent.audiovisual_sports_season]?',
#    '¿A qué hora y dónde dan [ent.audiovisual_tvshow_title]?',
#    '¿A qué hora y dónde es el [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]?',
#    '¿A qué hora y dónde se juegan los [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿A qué hora y en qué canal dan el programa de [ent.audiovisual_tvshow_title]?',
#    '¿A qué hora y en qué canal puedo ver el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿A qué hora y en qué canal se juega [ent.audiovisual_sports] please?',
#    '¿A qué hora y en qué canal se juega el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports] xfa?',
#    '¿Adónde se juega [ent.audiovisual_sports]?',
#    '¿Cuándo pasan [ent.audiovisual_sports]?',
#    '¿Cuándo pasan la [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿Cuándo transmiten los [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿Dónde pasan [ent.audiovisual_tvshow_title]?',
#    '¿Dónde pasan el programa de [ent.audiovisual_tvshow_title]?',
#    '¿Dónde pasan los [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿Dónde puedo ver el [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]?',
#    '¿Dónde se juega el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿Dónde y a qué hora se juega el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿En qué canal dan [ent.audiovisual_tvshow_title]?',
#    '¿En qué canal dan el [ent.audiovisual_sports_unit] [ent.time_instant]?',
#    '¿En qué canal es el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿En qué canal es el [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]?',
#    '¿En qué canal está [ent.audiovisual_tvseries_title]?',
#    '¿En qué canal está [ent.audiovisual_tvshow_title]?',
#    '¿En qué canal está el [ent.audiovisual_sports_unit]?',
#    '¿En qué canal se juega el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿En qué canal veo [ent.audiovisual_tvshow_title]?',
#    '¿En qué canal y a qué hora juegan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿En qué canal y a qué hora se juega la [ent.audiovisual_sports_season]?',
#    '¿En qué hora dan el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]?',
#    '¿En qué horario está [ent.audiovisual_tvseries_title]?',
#    '¿En qué horario está [ent.audiovisual_tvshow_title]?',
#    '¿En qué horario están pasando [ent.audiovisual_tvseries_title]?',
#    '¿En qué horario están pasando [ent.audiovisual_tvshow_title]?',
#    '¿En qué horario juegan [ent.audiovisual_sports_team] y [ent.audiovisual_sports_team]?',
#    '¿En qué horario y adónde es el [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team]?',
#    '¿En qué momento y dónde juegan la [ent.audiovisual_sports_season]?',
#    '¿Están pasando [ent.audiovisual_tvseries_title]?',
#    '¿Están pasando [ent.audiovisual_tvseries_title]? por la [ent.device_tv]?',
#    '¿Están pasando [ent.audiovisual_tvshow_title]?',
#    '¿Están pasando el [ent.audiovisual_sports_unit]?',
#    '¿Están pasando la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] por la [ent.device_tv]?',
#    '¿La [ent.audiovisual_sports_season] a dónde se juega?',
#    '¿La [ent.audiovisual_sports_season] a dónde y a qué hora juegan?',
#    '¿La [ent.audiovisual_sports_season] dónde se juega?',
#    '¿La [ent.audiovisual_sports_season] en qué canal y a qué hora juegan?',
#    '¿La [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season] a qué hora es?',
#    '¿Los [ent.audiovisual_sports_unit] de [ent.audiovisual_sports_team] a qué hora es por favor?',
#    '¿Por dónde dan [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]?',
#    '¿Por dónde dan [ent.audiovisual_tvseries_title]?',
#    '¿Por dónde dan [ent.audiovisual_tvshow_title]?',
#    '¿Por dónde pasan la [ent.audiovisual_sports_season]?',
#    '¿Por dónde se disputa la [ent.audiovisual_sports_season]?',
#    '¿Por dónde y cuándo se juega la [ent.audiovisual_sports_season]?',
#    '¿Sabés dónde pasan [ent.audiovisual_tvshow_title]?',
#    '¿X dónde dan [ent.audiovisual_sports]?',
#    '¿[ent.audiovisual_sports_team] contra [ent.audiovisual_sports_team] a qué hora y dónde juega?',
#    '¿[ent.audiovisual_sports_team] versus [ent.audiovisual_sports_team] a qué hora juegan?'],
#   'intent.tv.search': ['Algo con [ent.audiovisual_actor]',
#    'Algo con [ent.audiovisual_actor] por favor',
#    'Algo con [ent.audiovisual_actor] porfa',
#    'Algo con [ent.audiovisual_actor] y [ent.audiovisual_actor]',
#    'Algo con [ent.audiovisual_actor] y con [ent.audiovisual_actor]',
#    'Algo cuya directora es [ent.audiovisual_director]',
#    'Algo cuya directora es [ent.audiovisual_director] please',
#    'Algo cuyo director es [ent.audiovisual_director]',
#    'Algo de [ent.audiovisual_director] please',
#    'Algo de [ent.audiovisual_director] xfa',
#    'Algo de [ent.audiovisual_sports]',
#    'Algo de [ent.audiovisual_sports] por favor',
#    'Algo dirigido por [ent.audiovisual_director]',
#    'Algo donde aparece [ent.audiovisual_actor]',
#    'Algo donde aparezca [ent.audiovisual_actor]',
#    'Algo protagonizada por [ent.audiovisual_actor] plis',
#    'Algo que protagoniza [ent.audiovisual_actor]',
#    'Alguna [ent.audiovisual_genre]',
#    'Alguna [ent.audiovisual_genre] [ent.audiovisual_subgenre]',
#    'Alguna [ent.audiovisual_genre] cuya directora es [ent.audiovisual_director]',
#    'Alguna [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director]',
#    'Alguna [ent.audiovisual_genre] que protagoniza [ent.audiovisual_actor]',
#    'Alguna con [ent.audiovisual_actor]',
#    'Alguna de [ent.audiovisual_director] por favor',
#    'Alguna dirigida por [ent.audiovisual_director]',
#    'Algún [ent.audiovisual_genre] con [ent.audiovisual_actor]',
#    'Algún [ent.audiovisual_genre] con [ent.audiovisual_actor] y [ent.audiovisual_actor]',
#    'Algún [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director]',
#    'Algún [ent.audiovisual_genre] dirigida por [ent.audiovisual_director]',
#    'Algún [ent.audiovisual_genre] donde actúe [ent.audiovisual_actor]',
#    'Algún [ent.audiovisual_genre] donde aparezca [ent.audiovisual_actor]',
#    'Algún [ent.audiovisual_genre] protagonizada por [ent.audiovisual_actor]',
#    'Buscar [ent.audiovisual_tvseries_title]',
#    'Buscar una con [ent.audiovisual_actor]',
#    'El [ent.audiovisual_sports_season] porfavor',
#    'El [ent.audiovisual_sports_unit]',
#    'El [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    'El [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]',
#    'El [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]',
#    'El [ent.audiovisual_tv_episode_number] de la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title] por favor',
#    'La [ent.audiovisual_sports_season]',
#    'La [ent.audiovisual_sports_season] por favor',
#    'La [ent.audiovisual_sports_unit]',
#    'La [ent.audiovisual_sports_unit] de [ent.audiovisual_sports]',
#    'La [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title]',
#    'Los [ent.audiovisual_sports_unit]',
#    'Los [ent.audiovisual_sports_unit] de la [ent.audiovisual_sports_season]',
#    'Los [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]',
#    'Los [ent.audiovisual_sports_unit] por favor',
#    'Me gustaría ver alguna [ent.audiovisual_genre] [ent.audiovisual_subgenre]',
#    'Me gustaría ver el [ent.audiovisual_tv_episode_number] de la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title]',
#    'Mirar [ent.audiovisual_sports_unit]',
#    'Mostrame [ent.audiovisual_documental_title]',
#    'Mostrame algo [ent.audiovisual_subgenre]',
#    'Mostrame algo de [ent.audiovisual_subgenre]',
#    'Mostrame alguna de [ent.audiovisual_subgenre]',
#    'Mostrar [ent.audiovisual_actor]',
#    'Mostrar [ent.audiovisual_tvseries_title]',
#    'Please algo cuyo director es [ent.audiovisual_director]',
#    'Please algún [ent.audiovisual_genre]',
#    'Please ¿qué puedo mirar?',
#    'Plis [ent.audiovisual_actor]',
#    'Plis [ent.audiovisual_tvshow_title]',
#    'Plis alguna con [ent.audiovisual_actor]',
#    'Por favor [ent.audiovisual_film_title]',
#    'Por favor [ent.audiovisual_tvseries_title]',
#    'Por favor [ent.audiovisual_tvshow_title]',
#    'Por favor algo con [ent.audiovisual_actor]',
#    'Por favor algo donde aparece [ent.audiovisual_actor]',
#    'Por favor algo donde aparezca [ent.audiovisual_actor]',
#    'Por favor alguna [ent.audiovisual_genre] con [ent.audiovisual_actor] y [ent.audiovisual_actor]',
#    'Por favor buscar un [ent.audiovisual_genre] donde actúe [ent.audiovisual_actor]',
#    'Por favor el [ent.audiovisual_sports_unit]',
#    'Por favor la [ent.audiovisual_sports_unit]',
#    'Por favor la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title]',
#    'Por favor los [ent.audiovisual_sports_unit]',
#    'Por favor los [ent.audiovisual_sports_unit] del [ent.audiovisual_sports_season]',
#    'Por favor un [ent.audiovisual_genre]',
#    'Por favor una con [ent.audiovisual_actor]',
#    'Por favor ¿qué [ent.audiovisual_subgenre] de [ent.audiovisual_director] puedo mirar?',
#    'Por favor ¿qué puedo mirar?',
#    'Por favor ¿tenés una [ent.audiovisual_genre]?',
#    'Porfa [ent.audiovisual_documental_title]',
#    'Porfa [ent.audiovisual_sports_season]',
#    'Porfa [ent.audiovisual_tvseries_title] [ent.audiovisual_tv_episode_number]',
#    'Porfa [ent.audiovisual_tvshow_title]',
#    'Porfavor [ent.audiovisual_tvseries_title]',
#    'Porfis [ent.audiovisual_tvseries_title]',
#    'Quiero [ent.audiovisual_actor] por favor',
#    'Quiero [ent.audiovisual_film_title]',
#    'Quiero buscar un [ent.audiovisual_genre]',
#    'Quiero el [ent.audiovisual_tv_episode_number] de la [ent.audiovisual_tv_season_number] de [ent.audiovisual_tvseries_title]',
#    'Quiero que me muestres [ent.audiovisual_film_title]',
#    'Quiero que me muestres [ent.audiovisual_tvseries_title]',
#    'Quiero que me muestres [ent.audiovisual_tvshow_title]',
#    'Quiero ver una [ent.audiovisual_genre] [ent.audiovisual_subgenre]',
#    'Quisiera mirar un [ent.audiovisual_genre] [ent.audiovisual_subgenre]',
#    'Un [ent.audiovisual_genre]',
#    'Un [ent.audiovisual_genre] cuya directora es [ent.audiovisual_director]',
#    'Un [ent.audiovisual_genre] protagonizada por [ent.audiovisual_actor]',
#    'Una [ent.audiovisual_genre]',
#    'Una [ent.audiovisual_genre] [ent.audiovisual_subgenre]',
#    'Una [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director]',
#    'Una [ent.audiovisual_genre] de [ent.audiovisual_director]',
#    'Una [ent.audiovisual_genre] dirigida por [ent.audiovisual_director]',
#    'Una [ent.audiovisual_subgenre]',
#    'Una con [ent.audiovisual_actor]',
#    'Ver [ent.audiovisual_documental_title]',
#    'Ver [ent.audiovisual_sports]',
#    'Ver [ent.audiovisual_tvseries_title] please',
#    'Ver [ent.audiovisual_tvshow_title]',
#    'Ver alguna [ent.audiovisual_genre] cuya directora es [ent.audiovisual_director]',
#    'Xfa [ent.audiovisual_film_title]',
#    'Xfa [ent.audiovisual_tvshow_title]',
#    'Xfa algo cuya directora es [ent.audiovisual_director]',
#    'Xfa algo de [ent.audiovisual_director]',
#    '[ent.audiovisual_actor]',
#    '[ent.audiovisual_documental_title] por favor',
#    '[ent.audiovisual_film_title]',
#    '[ent.audiovisual_film_title] por favor',
#    '[ent.audiovisual_sports] por favor',
#    '[ent.audiovisual_sports_season] plis',
#    '[ent.audiovisual_sports_unit] xfa',
#    '[ent.audiovisual_tvseries_title] [ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tvseries_title] [ent.audiovisual_tv_season_number] [ent.audiovisual_tv_episode_number]',
#    '[ent.audiovisual_tvseries_title] [ent.audiovisual_tv_season_number] [ent.audiovisual_tv_episode_number] por favor',
#    '[ent.audiovisual_tvseries_title] [ent.audiovisual_tv_season_number] [ent.audiovisual_tv_episode_number] xfa',
#    '¿Hay algun [ent.audiovisual_genre] [ent.audiovisual_subgenre] para mirar?',
#    '¿Hay alguna [ent.audiovisual_genre] [ent.audiovisual_subgenre] para ver?',
#    '¿Me recomendás algo para ver? por favor',
#    '¿Me recomendás una [ent.audiovisual_genre]?',
#    '¿Qué [ent.audiovisual_genre] con [ent.audiovisual_actor] y [ent.audiovisual_actor] hay?',
#    '¿Qué [ent.audiovisual_genre] con [ent.audiovisual_actor] y con [ent.audiovisual_actor] puedo mirar?',
#    '¿Qué [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director] puedo mirar?',
#    '¿Qué [ent.audiovisual_genre] de [ent.audiovisual_actor] puedo mirar?',
#    '¿Qué [ent.audiovisual_genre] de [ent.audiovisual_director] tenés?',
#    '¿Qué [ent.audiovisual_genre] dirigida por [ent.audiovisual_director] puedo ver?',
#    '¿Qué [ent.audiovisual_genre] dirigido por [ent.audiovisual_director] puedo ver?',
#    '¿Qué [ent.audiovisual_genre] donde actúe [ent.audiovisual_actor] hay?',
#    '¿Qué [ent.audiovisual_genre] donde aparece [ent.audiovisual_actor] puedo mirar?',
#    '¿Qué [ent.audiovisual_genre] donde aparezca [ent.audiovisual_actor] tenés para ver?',
#    '¿Qué [ent.audiovisual_genre] protagonizada por [ent.audiovisual_actor] hay para ver?',
#    '¿Qué [ent.audiovisual_genre] que protagoniza [ent.audiovisual_actor] hay por favor?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] hay?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] y [ent.audiovisual_actor] hay para ver?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] y con [ent.audiovisual_actor] puedo ver?',
#    '¿Qué [ent.audiovisual_subgenre] con [ent.audiovisual_actor] y con [ent.audiovisual_actor] tenés para ver?',
#    '¿Qué [ent.audiovisual_subgenre] cuya directora es [ent.audiovisual_director] hay?',
#    '¿Qué [ent.audiovisual_subgenre] cuyo director es [ent.audiovisual_director] tenés?',
#    '¿Qué [ent.audiovisual_subgenre] de [ent.audiovisual_director] puedo ver?',
#    '¿Qué [ent.audiovisual_subgenre] dirigida por [ent.audiovisual_director] hay para ver?',
#    '¿Qué [ent.audiovisual_subgenre] dirigida por [ent.audiovisual_director] puedo ver?',
#    '¿Qué [ent.audiovisual_subgenre] donde actúa [ent.audiovisual_actor] puedo mirar?',
#    '¿Qué hay para ver?',
#    '¿Qué hay?',
#    '¿Qué me recomendás?',
#    '¿Qué puedo mirar por favor?',
#    '¿Qué puedo mirar?',
#    '¿Qué tenés para ver?',
#    '¿Tenés [ent.audiovisual_documental_title]?',
#    '¿Tenés algo con [ent.audiovisual_actor]?',
#    '¿Tenés algun [ent.audiovisual_genre]?',
#    '¿Tenés alguna [ent.audiovisual_genre]?',
#    '¿Tenés alguna con [ent.audiovisual_actor]?',
#    '¿Tenés alguna de [ent.audiovisual_director]?',
#    '¿Tenés algún [ent.audiovisual_genre] con [ent.audiovisual_actor] y con [ent.audiovisual_actor]?',
#    '¿Tenés algún [ent.audiovisual_genre] donde aparezca [ent.audiovisual_actor]?',
#    '¿Tenés un [ent.audiovisual_genre] cuyo director es [ent.audiovisual_director]?',
#    '¿Tenés un [ent.audiovisual_genre] donde actúa [ent.audiovisual_actor]?',
#    '¿Tenés un [ent.audiovisual_genre] donde aparece [ent.audiovisual_actor]?'],
#   'intent.tv.search_similar': ['Algo [ent.audiovisual_subgenre] como [ent.audiovisual_film_title]',
#    'Algo [ent.audiovisual_subgenre] de la onda de [ent.audiovisual_film_title]',
#    'Algo [ent.audiovisual_subgenre] de la onda de [ent.audiovisual_film_title] xfa',
#    'Algo [ent.audiovisual_subgenre] de la onda de [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] del estilo de [ent.audiovisual_film_title]',
#    'Algo [ent.audiovisual_subgenre] del estilo de [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] del tipo de [ent.audiovisual_film_title]',
#    'Algo [ent.audiovisual_subgenre] del tipo de [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] onda [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] parecida a [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_tvshow_title]',
#    'Algo [ent.audiovisual_subgenre] que sea como [ent.audiovisual_tvseries_title]',
#    'Algo [ent.audiovisual_subgenre] que sea tipo [ent.audiovisual_tvshow_title]',
#    'Algo como [ent.audiovisual_film_title]',
#    'Algo como [ent.audiovisual_tvseries_title]',
#    'Algo como [ent.audiovisual_tvshow_title]',
#    'Algo de [ent.audiovisual_actor] que se parezca a [ent.audiovisual_tvshow_title]',
#    'Algo de [ent.audiovisual_director] parecido a [ent.audiovisual_film_title]',
#    'Algo de [ent.audiovisual_subgenre] como [ent.audiovisual_film_title]',
#    'Algo de la onda de [ent.audiovisual_tvshow_title]',
#    'Algo del estilo de [ent.audiovisual_film_title]',
#    'Algo del estilo de [ent.audiovisual_tvshow_title]',
#    'Algo del tipo de [ent.audiovisual_film_title]',
#    'Algo del tipo de [ent.audiovisual_tvshow_title]',
#    'Algo onda [ent.audiovisual_film_title]',
#    'Algo parecido a [ent.audiovisual_film_title]',
#    'Algo parecido a [ent.audiovisual_tvseries_title]',
#    'Algo parecido a [ent.audiovisual_tvseries_title] xfa',
#    'Algo que se parezca a [ent.audiovisual_film_title]',
#    'Algo que sea del estilo de [ent.audiovisual_film_title]',
#    'Algo que sea del estilo de [ent.audiovisual_film_title] por favor',
#    'Algo que sea tipo [ent.audiovisual_tvseries_title]',
#    'Algo tipo [ent.audiovisual_film_title]',
#    'Algo tipo [ent.audiovisual_tvseries_title]',
#    'Algo tipo [ent.audiovisual_tvshow_title]',
#    'Alguna [ent.audiovisual_genre] del estilo de [ent.audiovisual_tvseries_title]',
#    'Alguna [ent.audiovisual_genre] del estilo de [ent.audiovisual_tvshow_title] por favor',
#    'Alguna [ent.audiovisual_genre] que sea como [ent.audiovisual_tvshow_title]',
#    'Alguna [ent.audiovisual_genre] que sea tipo de [ent.audiovisual_tvseries_title]',
#    'Alguna [ent.audiovisual_genre] similar a [ent.audiovisual_documental_title] xfa',
#    'Alguna [ent.audiovisual_genre] similar a [ent.audiovisual_film_title]',
#    'Alguna [ent.audiovisual_subgenre] como [ent.audiovisual_film_title]',
#    'Alguna [ent.audiovisual_subgenre] como [ent.audiovisual_tvseries_title]',
#    'Alguna [ent.audiovisual_subgenre] como [ent.audiovisual_tvshow_title]',
#    'Alguna [ent.audiovisual_subgenre] como [ent.audiovisual_tvshow_title] plis',
#    'Alguna [ent.audiovisual_subgenre] de la onda de [ent.audiovisual_tvseries_title] por favor',
#    'Alguna [ent.audiovisual_subgenre] onda [ent.audiovisual_film_title]',
#    'Alguna [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_tvshow_title]',
#    'Alguna [ent.audiovisual_subgenre] que sea del estilo de [ent.audiovisual_tvseries_title]',
#    'Alguna [ent.audiovisual_subgenre] tipo [ent.audiovisual_tvshow_title]',
#    'Alguna como [ent.audiovisual_tvseries_title]',
#    'Algún [ent.audiovisual_genre] parecido a [ent.audiovisual_documental_title]',
#    'Mostrame algo [ent.audiovisual_subgenre] como [ent.audiovisual_film_title]',
#    'Mostrame algo de [ent.audiovisual_subgenre] tipo [ent.audiovisual_tvseries_title]',
#    'Mostrame algo que se parezca a [ent.audiovisual_tvseries_title]',
#    'Mostrame alguna [ent.audiovisual_genre] que sea tipo [ent.audiovisual_documental_title]',
#    'Mostrame alguna [ent.audiovisual_subgenre] como [ent.audiovisual_tvshow_title]',
#    'Mostrame alguna de [ent.audiovisual_subgenre] tipo [ent.audiovisual_tvshow_title]',
#    'Por favor algo [ent.audiovisual_subgenre] que sea como [ent.audiovisual_tvshow_title]',
#    'Por favor algo tipo [ent.audiovisual_tvseries_title]',
#    'Por favor alguna [ent.audiovisual_genre] del estilo de [ent.audiovisual_film_title]',
#    'Por favor ¿qué [ent.audiovisual_genre] de la onda de [ent.audiovisual_tvshow_title] tenés para mí?',
#    'Por favor ¿qué [ent.audiovisual_genre] que sea tipo de [ent.audiovisual_film_title] me recomendás?',
#    'Por favor ¿qué puedo ver parecido a [ent.audiovisual_documental_title]?',
#    'Porfavor algo que se parezca a [ent.audiovisual_film_title]',
#    'Porfis una [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_tvseries_title]',
#    'Porfis ¿qué [ent.audiovisual_genre] onda [ent.audiovisual_documental_title] me recomendás?',
#    'Quiero alguna [ent.audiovisual_genre] que sea como [ent.audiovisual_tvshow_title]',
#    'Qué tenés de [ent.audiovisual_director] como [ent.audiovisual_film_title]',
#    'Un [ent.audiovisual_genre] como [ent.audiovisual_tvshow_title]',
#    'Un [ent.audiovisual_genre] del estilo de [ent.audiovisual_documental_title]',
#    'Un [ent.audiovisual_genre] onda [ent.audiovisual_documental_title] porfis',
#    'Un [ent.audiovisual_genre] onda [ent.audiovisual_tvshow_title] xfa',
#    'Un [ent.audiovisual_genre] similar a [ent.audiovisual_tvseries_title]',
#    'Un [ent.audiovisual_genre] tipo [ent.audiovisual_documental_title]',
#    'Una [ent.audiovisual_genre] de la onda de [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_genre] de la onda de [ent.audiovisual_tvshow_title]',
#    'Una [ent.audiovisual_genre] onda [ent.audiovisual_tvshow_title]',
#    'Una [ent.audiovisual_genre] que sea como [ent.audiovisual_tvshow_title]',
#    'Una [ent.audiovisual_genre] que sea tipo [ent.audiovisual_documental_title]',
#    'Una [ent.audiovisual_genre] similar a [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_subgenre] como [ent.audiovisual_film_title]',
#    'Una [ent.audiovisual_subgenre] como [ent.audiovisual_film_title] por favor',
#    'Una [ent.audiovisual_subgenre] como [ent.audiovisual_tvshow_title]',
#    'Una [ent.audiovisual_subgenre] del estilo de [ent.audiovisual_tvshow_title] por favor',
#    'Una [ent.audiovisual_subgenre] onda [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_subgenre] parecida a [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_film_title]',
#    'Una [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_subgenre] que sea como [ent.audiovisual_film_title]',
#    'Una [ent.audiovisual_subgenre] que sea como [ent.audiovisual_tvshow_title]',
#    'Una [ent.audiovisual_subgenre] que sea del estilo de [ent.audiovisual_tvseries_title]',
#    'Una [ent.audiovisual_subgenre] que sea tipo de [ent.audiovisual_film_title]',
#    'Una [ent.audiovisual_subgenre] tipo [ent.audiovisual_tvshow_title]',
#    'Una de [ent.audiovisual_actor] parecida a [ent.audiovisual_tvshow_title]',
#    'Una de [ent.audiovisual_director] de la onda de [ent.audiovisual_film_title]',
#    'Una tipo [ent.audiovisual_tvshow_title]',
#    'Uno tipo [ent.audiovisual_documental_title]',
#    'Xfa algo [ent.audiovisual_subgenre] parecido a [ent.audiovisual_tvshow_title]',
#    '[ent.audiovisual_genre] como [ent.audiovisual_film_title]',
#    '[ent.audiovisual_genre] como [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_genre] de la onda de [ent.audiovisual_documental_title]',
#    '[ent.audiovisual_genre] del estilo de [ent.audiovisual_documental_title] porfa',
#    '[ent.audiovisual_genre] onda [ent.audiovisual_documental_title] por favor',
#    '[ent.audiovisual_genre] que se parezca a [ent.audiovisual_film_title]',
#    '[ent.audiovisual_genre] que se parezca a [ent.audiovisual_tvshow_title]',
#    '[ent.audiovisual_genre] que sea como [ent.audiovisual_documental_title]',
#    '[ent.audiovisual_genre] que sea como [ent.audiovisual_film_title]',
#    '[ent.audiovisual_genre] que sea como [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_genre] que sea del estilo de [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_genre] que sea tipo [ent.audiovisual_tvshow_title]',
#    '[ent.audiovisual_genre] que sea tipo de [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_genre] similar a [ent.audiovisual_film_title]',
#    '[ent.audiovisual_genre] tipo [ent.audiovisual_tvseries_title]',
#    '[ent.audiovisual_genre] tipo [ent.audiovisual_tvshow_title]?',
#    '¿Qué [ent.audiovisual_genre] como [ent.audiovisual_documental_title] puedo ver?',
#    '¿Qué [ent.audiovisual_genre] como [ent.audiovisual_film_title] tenés para recomendarme?',
#    '¿Qué [ent.audiovisual_genre] de la onda de [ent.audiovisual_documental_title] puedo ver?',
#    '¿Qué [ent.audiovisual_genre] del estilo de [ent.audiovisual_tvseries_title] me recomendás?',
#    '¿Qué [ent.audiovisual_genre] del estilo de [ent.audiovisual_tvshow_title] me sugerís por favor?',
#    '¿Qué [ent.audiovisual_genre] onda [ent.audiovisual_documental_title] puedo ver?',
#    '¿Qué [ent.audiovisual_genre] onda [ent.audiovisual_documental_title] tenés?',
#    '¿Qué [ent.audiovisual_genre] que se parezca a [ent.audiovisual_tvseries_title] tenés?',
#    '¿Qué [ent.audiovisual_genre] que sea como [ent.audiovisual_documental_title] me sugerís por favor?',
#    '¿Qué [ent.audiovisual_genre] que sea como [ent.audiovisual_documental_title] tenés para recomendarme?',
#    '¿Qué [ent.audiovisual_genre] que sea como [ent.audiovisual_film_title] tenés?',
#    '¿Qué [ent.audiovisual_genre] que sea del estilo de [ent.audiovisual_film_title] tenés?',
#    '¿Qué [ent.audiovisual_genre] que sea del estilo de [ent.audiovisual_tvshow_title] hay?',
#    '¿Qué [ent.audiovisual_genre] que sea tipo de [ent.audiovisual_film_title] me recomendás?',
#    '¿Qué [ent.audiovisual_genre] que sea tipo de [ent.audiovisual_tvseries_title] hay para mí por favor?',
#    '¿Qué [ent.audiovisual_genre] que sea tipo de [ent.audiovisual_tvseries_title] tenés para mí?',
#    '¿Qué [ent.audiovisual_genre] similar a [ent.audiovisual_film_title] tenés?',
#    '¿Qué [ent.audiovisual_genre] similar a [ent.audiovisual_tvseries_title] me sugerís?',
#    '¿Qué [ent.audiovisual_genre] tipo [ent.audiovisual_tvseries_title] hay?',
#    '¿Qué [ent.audiovisual_genre] tipo [ent.audiovisual_tvseries_title] tenés para sugerirme porfa?',
#    '¿Qué hay de la onda de [ent.audiovisual_documental_title]?',
#    '¿Qué hay de la onda de [ent.audiovisual_tvseries_title]?',
#    '¿Qué hay de la onda de [ent.audiovisual_tvshow_title]?',
#    '¿Qué hay que sea como [ent.audiovisual_documental_title]?',
#    '¿Qué hay que sea del estilo de [ent.audiovisual_documental_title]?',
#    '¿Qué hay similar a [ent.audiovisual_documental_title]?',
#    '¿Qué hay tipo [ent.audiovisual_documental_title]?',
#    '¿Qué puedo ver como [ent.audiovisual_tvseries_title]?',
#    '¿Qué puedo ver de la onda de [ent.audiovisual_documental_title]?',
#    '¿Qué puedo ver de la onda de [ent.audiovisual_tvshow_title]?',
#    '¿Qué puedo ver del estilo de [ent.audiovisual_documental_title]?',
#    '¿Qué puedo ver onda [ent.audiovisual_tvseries_title] por favor?',
#    '¿Qué puedo ver que se parezca a [ent.audiovisual_documental_title]?',
#    '¿Qué puedo ver que se parezca a [ent.audiovisual_film_title]?',
#    '¿Qué puedo ver que se parezca a [ent.audiovisual_tvshow_title]?',
#    '¿Qué puedo ver que sea del estilo de [ent.audiovisual_film_title]?',
#    '¿Qué puedo ver que sea del estilo de [ent.audiovisual_tvseries_title]?',
#    '¿Qué puedo ver que sea tipo [ent.audiovisual_documental_title]?',
#    '¿Qué puedo ver tipo [ent.audiovisual_documental_title]?',
#    '¿Qué tenés como [ent.audiovisual_documental_title]?',
#    '¿Qué tenés de la onda de [ent.audiovisual_tvseries_title]?',
#    '¿Qué tenés del estilo de [ent.audiovisual_documental_title]?',
#    '¿Qué tenés parecido a [ent.audiovisual_film_title] por favor?',
#    '¿Qué tenés que se parezca a [ent.audiovisual_documental_title]?',
#    '¿Qué tenés que sea del estilo de [ent.audiovisual_documental_title] please?',
#    '¿Qué tenés que sea parecido a [ent.audiovisual_documental_title] please?',
#    '¿Qué tenés tipo [ent.audiovisual_documental_title] porfavor?',
#    '¿Qué tenés tipo [ent.audiovisual_documental_title]?',
#    '¿Tenés algo [ent.audiovisual_subgenre] que se parezca a [ent.audiovisual_tvshow_title]?',
#    '¿Tenés algo como [ent.audiovisual_film_title]?',
#    '¿Tenés algo como [ent.audiovisual_tvseries_title]?',
#    '¿Tenés algo de la onda de [ent.audiovisual_documental_title]?',
#    '¿Tenés algo de la onda de [ent.audiovisual_film_title]?',
#    '¿Tenés algo del estilo de [ent.audiovisual_documental_title] por favor?',
#    '¿Tenés algo parecido a [ent.audiovisual_documental_title]?',
#    '¿Tenés algo que se parezca a [ent.audiovisual_film_title]?',
#    '¿Tenés algo que se parezca a [ent.audiovisual_tvshow_title]?',
#    '¿Tenés algo similar a [ent.audiovisual_documental_title]?'],
#   'None': ['App',
#    'Contame, ¿Qué comiste?',
#    'Eso no me da resultado',
#    'Mis contactos',
#    'No app',
#    'No deberíamos',
#    'No hay',
#    'No me acuerdo de mi contraseña',
#    'No me gusta',
#    'No me sirve',
#    'No puedo',
#    'No queríamos',
#    'No quieres',
#    'No recuerdo la contraseña',
#    'No sabes',
#    'No servís',
#    'No servís para nada',
#    'No somos',
#    'No tenemos',
#    'No tienes',
#    'No vales',
#    'Sos nada',
#    '¡Qué buena voz tenés!',
#    '¿A qué cole vas?',
#    '¿A qué hora termina tu horario laboral?',
#    '¿A qué hora terminas?',
#    '¿Alta?',
#    '¿Argentina?',
#    '¿Baja?',
#    '¿Celiaca?',
#    '¿Como Barbie?',
#    '¿Comés carne?',
#    '¿Comés verdura?',
#    '¿Cuál es tu color preferido?',
#    '¿Cuál es tu horario laboral?',
#    '¿Cuál es tu segundo nombre?',
#    '¿Cuáles animales te gustan?',
#    '¿Cuántas horas trabajás?',
#    '¿Cuánto cobrás?',
#    '¿Cuánto medís?',
#    '¿Cuánto pesás?',
#    '¿Cuántos años tenés?',
#    '¿Cómo estas vestida?',
#    '¿Cómo está formada tu familia?',
#    '¿Cómo físicamente?',
#    '¿Cómo se llama tu novio?',
#    '¿Cómo sos?',
#    '¿Cómo vas vestida?',
#    '¿Cómo?',
#    '¿De dónde?',
#    '¿De qué color de ojos tenés?',
#    '¿De qué cuadro?',
#    '¿De qué país?',
#    '¿De qué provincia?',
#    '¿De verdad?',
#    '¿De zonanorte?',
#    '¿Del conurbano?',
#    '¿Dónde estudiaste?',
#    '¿Dónde naciste?',
#    '¿Dónde trabajás?',
#    '¿Dónde vivís?',
#    '¿En qué barrio vivís?',
#    '¿Española?',
#    '¿Estás casada?',
#    '¿Estás divorciada?',
#    '¿Estás soltera?',
#    '¿Europea?',
#    '¿Flaca?',
#    '¿Fumás?',
#    '¿Gorda?',
#    '¿Guapa?',
#    '¿Hacés algo de ejercicio?',
#    '¿Hacés deporte?',
#    '¿Hacés deportes?',
#    '¿Hacés dieta?',
#    '¿Has estudiado?',
#    '¿Hija?',
#    '¿Huérfana?',
#    '¿Jugamos a la play?',
#    '¿Jugamos en Red?',
#    '¿Jugas al Roblox?',
#    '¿Jugas conmigo a la XBOX?',
#    '¿Madre?',
#    '¿Me decís tu correo?',
#    '¿Me pasas tu mail?',
#    '¿Mirás Netflix?',
#    '¿Máquina o humano?',
#    '¿Normal?',
#    '¿Nos vamos de viaje?',
#    '¿Pelirroja?',
#    '¿Petisa?',
#    '¿Queres algo conmigo?',
#    '¿Queres salir conmigo?',
#    '¿Querés ser mi esposa?',
#    '¿Querés ser mi novia?',
#    '¿Querés ser mi pareja?',
#    '¿Quién sos?',
#    '¿Quién?',
#    '¿Qué comiste hoy?',
#    '¿Qué dieta hacés?',
#    '¿Qué día es hoy?',
#    '¿Qué edad tenés?',
#    '¿Qué físico tenés?',
#    '¿Qué hacés en tu tiempo libre?',
#    '¿Qué hiciste anoche?',
#    '¿Qué juegos de play tenés?',
#    '¿Qué musica te gusta?',
#    '¿Qué ropa tenés puesta?',
#    '¿Qué serie estás mirando?',
#    '¿Qué sos?',
#    '¿Qué te gusta comer?',
#    '¿Qué te gusta leer?',
#    '¿Qué temperatura hace?',
#    '¿Rellenita?',
#    '¿Rubia?',
#    '¿Sabés bailar?',
#    '¿Sos hombre?',
#    '¿Sos mujer?',
#    '¿Sos un robot?',
#    '¿Sos una persona?',
#    '¿Sosa?',
#    '¿Sueles ir al gimnasio?',
#    '¿Te gusta Netflix?',
#    '¿Te gusta el café?',
#    '¿Te gusta el pescado?',
#    '¿Te gusta el sushi?',
#    '¿Te gusta el té?',
#    '¿Te gusta la música?',
#    '¿Te gustan las mujeres?',
#    '¿Te gustan los gatos?',
#    '¿Te gustan los hombres?',
#    '¿Te gustan los niños?',
#    '¿Te gustan los perros?',
#    '¿Te paso a buscar?',
#    '¿Tenés descendencia?',
#    '¿Tenés hermanos?',
#    '¿Tenés hijos?',
#    '¿Tenés instagram?',
#    '¿Tenés linkedin?',
#    '¿Tenés mascotas?',
#    '¿Tenés novio?',
#    '¿Tenés sobrenombre?',
#    '¿Tenés spotify?',
#    '¿Tenés tu blog?',
#    '¿Tenés twitter?',
#    '¿Un robot?',
#    '¿Una persona?',
#    '¿Vegana?',
#    '¿Vegetariana?']}}

# %%
# Out:
# {"intent.tv.content_get_info, ('[ent.audiovisual_channel]',)": 23,
#  "intent.tv.content_get_info, ('[ent.audiovisual_channel]', '[ent.time_interval]')": 13,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]', '[ent.time_instant]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.audiovisual_genre]')": 6,
#  "intent.tv.content_get_info, ('[ent.device_tv]',)": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.time_interval]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.time_instant]')": 6,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.time_interval]', '[ent.device_tv]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.audiovisual_channel]')": 8,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.audiovisual_channel]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_channel]', '[ent.time_interval]')": 3,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.device_tv]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.device_tv]')": 3,
#  "intent.tv.content_get_info, ('[ent.device_tv]', '[ent.time_interval]')": 4,
#  "intent.tv.content_get_info, ('[ent.time_instant]',)": 8,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.device_tv]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.audiovisual_genre]')": 5,
#  "intent.tv.content_get_info, ('[ent.audiovisual_channel]', '[ent.time_instant]')": 4,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_channel]')": 10,
#  "intent.tv.content_get_info, ('[ent.device_tv]', '[ent.time_instant]')": 4,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.time_instant]')": 3,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]')": 3,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.time_instant]', '[ent.device_tv]')": 3,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.time_interval]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_channel]')": 1,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.time_interval]', '[ent.audiovisual_genre]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.device_tv]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.audiovisual_channel]')": 3,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.audiovisual_sports_unit]')": 1,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.time_instant]', '[ent.audiovisual_sports_unit]')": 1,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.time_instant]')": 2,
#  "intent.tv.content_get_info, ('[ent.time_interval]', '[ent.audiovisual_sports_unit]')": 1,
#  "intent.tv.content_get_info, ('[ent.time_interval]',)": 6,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]', '[ent.time_interval]')": 2,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.device_tv]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.time_interval]', '[ent.audiovisual_channel]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]', '[ent.time_instant]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.device_tv]', '[ent.time_interval]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.device_tv]', '[ent.time_instant]')": 2,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]', '[ent.device_tv]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.device_tv]', '[ent.time_instant]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.device_tv]', '[ent.time_interval]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_genre]', '[ent.time_interval]', '[ent.audiovisual_channel]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.audiovisual_channel]')": 2,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.time_instant]')": 5,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.time_instant]', '[ent.device_tv]')": 2,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_channel]')": 2,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.time_interval]', '[ent.device_tv]')": 1,
#  "intent.tv.content_get_info, ('[ent.audiovisual_subgenre]', '[ent.time_interval]')": 1,
#  "intent.tv.content_get_info, ('[ent.time_instant]', '[ent.time_interval]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]', '[ent.device_tv]')": 6,
#  "intent.tv.display, ('[ent.audiovisual_tv_episode_number]', '[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_sports_season]', '[ent.device_tv]')": 4,
#  "intent.tv.display, ('[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]', '[ent.device_tv]')": 3,
#  "intent.tv.display, ('[ent.audiovisual_genre]', '[ent.device_tv]')": 3,
#  "intent.tv.display, ('[ent.audiovisual_sports_unit]', '[ent.device_tv]')": 8,
#  "intent.tv.display, ('[ent.audiovisual_documental_title]', '[ent.device_tv]')": 6,
#  "intent.tv.display, ('[ent.audiovisual_sports]', '[ent.device_tv]')": 7,
#  "intent.tv.display, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_tvseries_title]', '[ent.device_tv]')": 14,
#  "intent.tv.display, ('[ent.audiovisual_actor]', '[ent.device_tv]')": 2,
#  "intent.tv.display, ('[ent.audiovisual_tvshow_title]', '[ent.device_tv]')": 4,
#  "intent.tv.display, ('[ent.audiovisual_film_title]', '[ent.device_tv]')": 5,
#  "intent.tv.display, ('[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tv_episode_number]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_documental_title]',)": 1,
#  "intent.tv.display, ('[ent.audiovisual_film_title]',)": 1,
#  "intent.tv.display, ('[ent.audiovisual_tvseries_title]',)": 1,
#  "intent.tv.display, ('[ent.device_tv]', '[ent.audiovisual_film_title]')": 1,
#  "intent.tv.display, ('[ent.device_tv]', '[ent.audiovisual_tvseries_title]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_episode_number]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_subgenre]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_genre]', '[ent.audiovisual_actor]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_genre]', '[ent.audiovisual_actor]', '[ent.audiovisual_actor]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_genre]', '[ent.audiovisual_director]', '[ent.device_tv]')": 2,
#  "intent.tv.display, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]', '[ent.audiovisual_actor]', '[ent.device_tv]')": 1,
#  "intent.tv.display, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_director]', '[ent.device_tv]')": 2,
#  "intent.tv.display, ('[ent.device_tv]',)": 7,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]')": 16,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_team]',)": 15,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_tvshow_title]',)": 37,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_season]',)": 33,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports]',)": 13,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_unit]',)": 13,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_team]')": 14,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_team]', '[ent.audiovisual_sports_team]')": 20,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]')": 17,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_tvseries_title]',)": 9,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_tv_episode_number]', '[ent.audiovisual_tvseries_title]')": 1,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_season]', '[ent.audiovisual_sports]')": 2,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_sports_unit]', '[ent.time_instant]')": 1,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_tvseries_title]', '[ent.device_tv]')": 1,
#  "intent.tv.question_time_loc, ('[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]', '[ent.device_tv]')": 1,
#  "intent.tv.search, ('[ent.audiovisual_actor]',)": 21,
#  "intent.tv.search, ('[ent.audiovisual_actor]', '[ent.audiovisual_actor]')": 2,
#  "intent.tv.search, ('[ent.audiovisual_director]',)": 12,
#  "intent.tv.search, ('[ent.audiovisual_sports]',)": 4,
#  "intent.tv.search, ('[ent.audiovisual_genre]',)": 10,
#  "intent.tv.search, ('[ent.audiovisual_genre]', '[ent.audiovisual_subgenre]')": 7,
#  "intent.tv.search, ('[ent.audiovisual_genre]', '[ent.audiovisual_director]')": 14,
#  "intent.tv.search, ('[ent.audiovisual_genre]', '[ent.audiovisual_actor]')": 16,
#  "intent.tv.search, ('[ent.audiovisual_genre]', '[ent.audiovisual_actor]', '[ent.audiovisual_actor]')": 5,
#  "intent.tv.search, ('[ent.audiovisual_tvseries_title]',)": 7,
#  "intent.tv.search, ('[ent.audiovisual_sports_season]',)": 5,
#  "intent.tv.search, ('[ent.audiovisual_sports_unit]',)": 9,
#  "intent.tv.search, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports]')": 2,
#  "intent.tv.search, ('[ent.audiovisual_sports_unit]', '[ent.audiovisual_sports_season]')": 5,
#  "intent.tv.search, ('[ent.audiovisual_tv_episode_number]', '[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]')": 3,
#  "intent.tv.search, ('[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tvseries_title]')": 2,
#  "intent.tv.search, ('[ent.audiovisual_documental_title]',)": 5,
#  "intent.tv.search, ('[ent.audiovisual_subgenre]',)": 4,
#  "intent.tv.search, ('[ent.audiovisual_tvshow_title]',)": 6,
#  "intent.tv.search, ('[ent.audiovisual_film_title]',)": 6,
#  "intent.tv.search, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_director]')": 6,
#  "intent.tv.search, ('[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_episode_number]')": 2,
#  "intent.tv.search, ('[ent.audiovisual_tvseries_title]', '[ent.audiovisual_tv_season_number]', '[ent.audiovisual_tv_episode_number]')": 3,
#  "intent.tv.search, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]')": 2,
#  "intent.tv.search, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_actor]', '[ent.audiovisual_actor]')": 3,
#  "intent.tv.search_similar, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_film_title]')": 14,
#  "intent.tv.search_similar, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_tvseries_title]')": 15,
#  "intent.tv.search_similar, ('[ent.audiovisual_subgenre]', '[ent.audiovisual_tvshow_title]')": 15,
#  "intent.tv.search_similar, ('[ent.audiovisual_film_title]',)": 16,
#  "intent.tv.search_similar, ('[ent.audiovisual_tvseries_title]',)": 14,
#  "intent.tv.search_similar, ('[ent.audiovisual_tvshow_title]',)": 10,
#  "intent.tv.search_similar, ('[ent.audiovisual_actor]', '[ent.audiovisual_tvshow_title]')": 2,
#  "intent.tv.search_similar, ('[ent.audiovisual_director]', '[ent.audiovisual_film_title]')": 3,
#  "intent.tv.search_similar, ('[ent.audiovisual_genre]', '[ent.audiovisual_tvseries_title]')": 17,
#  "intent.tv.search_similar, ('[ent.audiovisual_genre]', '[ent.audiovisual_tvshow_title]')": 14,
#  "intent.tv.search_similar, ('[ent.audiovisual_genre]', '[ent.audiovisual_documental_title]')": 18,
#  "intent.tv.search_similar, ('[ent.audiovisual_genre]', '[ent.audiovisual_film_title]')": 12,
#  "intent.tv.search_similar, ('[ent.audiovisual_documental_title]',)": 23}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fcd9a0cb28e6> in <module>
#       6
#       7
# ----> 8     entidades = find_entities(intent)
#       9     cuenta.append(entidades)
#      10
#
# <ipython-input-7-43487643e12c> in find_entities(dic)
#       4     out = []
#       5
# ----> 6     for intent in dic['intents'].keys():
#       7         out.append(intent)
#       8
#
# TypeError: string indices must be integers
